# %% [markdown]
# # Question 1

# %% [markdown]
# What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
# Matplotlib.

# %%
'''
Matplotlib is a Python data visualization library that produces high-quality static, animated, and interactive plots. 
It is widely used for creating visual representations of data in various formats.


Matplotlib is used majorly because Matplotlib's Pyplot module provides a simple interface for creating various types of plots.

Here are five types of plots that can be created using Pyplot:
1. Line Plot
2. Scatter Plot
3. Histogram
4. Bar Plot
5. Pie Chart
'''
# Out:
# "\nMatplotlib is a Python data visualization library that produces high-quality static, animated, and interactive plots. \nIt is widely used for creating visual representations of data in various formats.\n\n\nMatplotlib is used majorly because Matplotlib's Pyplot module provides a simple interface for creating various types of plots.\n\nHere are five types of plots that can be created using Pyplot:\n1. Line Plot\n2. Scatter Plot\n3. Histogram\n4. Bar Plot\n5. Pie Chart\n"

# %% [markdown]
# # Question 2

# %% [markdown]
# What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# plot a scatter plot.
#
# import numpy as np
#
# np.random.seed(3)
#
# x = 3 + np.random.normal(0, 2, 50)
#
# y = 3 + np.random.normal(0, 2, len(x))
#
# Note: Also add title, xlabel, and ylabel to the plot.

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(3)

# Generate data for x and y
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

# Create a scatter plot
plt.scatter(x, y)

# Add title, xlabel, and ylabel
plt.title('Scatter Plot of x and y')
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')

# Show the plot
plt.show()

# %% [markdown]
# # Question 3

# %% [markdown]
# Why is the subplot() function used? Draw four line plots using the subplot() function.
# Use the following data:
#
# import numpy as np
#
# For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
#
# For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
#
# For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
#
# For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

# %%
'''
the subplot function in Matplotlib is used to create multiple plots within a single figure. 
It allows to arrange plots in a grid, specifying the number of rows and columns. 
'''
# Here's an example of how to use subplot() to draw four line plots with the given data:

import numpy as np
import matplotlib.pyplot as plt

# Data for line plots
x = np.array([0, 1, 2, 3, 4, 5])

y1 = np.array([0, 100, 200, 300, 400, 500])
y2 = np.array([50, 20, 40, 20, 60, 70])
y3 = np.array([10, 20, 30, 40, 50, 60])
y4 = np.array([200, 350, 250, 550, 450, 150])

# Create a figure with subplots
plt.figure(figsize=(12, 8))

# Plot 1
plt.subplot(2, 2, 1)
plt.plot(x, y1)
plt.title('Line Plot 1')

# Plot 2
plt.subplot(2, 2, 2)
plt.plot(x, y2)
plt.title('Line Plot 2')

# Plot 3
plt.subplot(2, 2, 3)
plt.plot(x, y3)
plt.title('Line Plot 3')

# Plot 4
plt.subplot(2, 2, 4)
plt.plot(x, y4)
plt.title('Line Plot 4')

# Adjust layout for better spacing
plt.tight_layout()

# Show the plots
plt.show()

# %% [markdown]
# # Question 4

# %% [markdown]
# What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
#
# import numpy as np
#
# company = np.array(["Apple", "Microsoft", "Google", "AMD"])
#
# profit = np.array([3000, 8000, 1000, 10000])

# %%
'''
A bar plot is a type of data visualization that represents categorical data with rectangular bars.


Bar plots are useful for visualizing and comparing discrete data points.
'''

import numpy as np
import matplotlib.pyplot as plt

company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# Bar plot
plt.figure(figsize=(8, 6))
plt.bar(company, profit, color='skyblue')
plt.title('Bar Plot of Company Profits')
plt.xlabel('Company')
plt.ylabel('Profit (in millions)')
plt.show()

# Horizontal bar plot
plt.figure(figsize=(8, 6))
plt.barh(company, profit, color='lightcoral')
plt.title('Horizontal Bar Plot of Company Profits')
plt.xlabel('Profit (in millions)')
plt.ylabel('Company')
plt.show()

# %% [markdown]
# # Question 5

# %% [markdown]
# What is a box plot? Why is it used? Using the following data plot a box plot.
#
# box1 = np.random.normal(100, 10, 200)
#
# box2 = np.random.normal(90, 20, 200)

# %%
'''
A box plot, is a statistical visualization tool that displays the distribution and summary statistics of a dataset. 
It is particularly useful for comparing the central tendency, spread, and skewness of different datasets or variables.


A box plot consists of a rectangular "box" that represents the interquartile range (IQR) of the data, 
with a line inside the box indicating the median. Whiskers extend from the box to show the range of the data, and any points outside the whiskers are considered outliers
