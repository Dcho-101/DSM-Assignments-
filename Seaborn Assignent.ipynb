# %% [markdown]
# # Question 1

# %% [markdown]
# Name any five plots that we can plot using the Seaborn library. Also, state the uses of each plot.

# %%
'''
1. Scatter Plot

Scatter plots are used to visualize the relationship between two continuous variables.

2. Line Plot

Line plots are useful for visualizing trends and patterns in time-series data.

3. Histogram

Histograms are used to display the distribution of a single continuous variable. 

4. Bar Plot

Bar plots are effective for displaying and comparing the values of different categories or groups.

5. Box Plot

Box plots are used to visualize the distribution of a continuous variable across different categories.
'''
# Out:
# '\n1. Scatter Plot\n\nScatter plots are used to visualize the relationship between two continuous variables.\n\n2. Line Plot\n\nLine plots are useful for visualizing trends and patterns in time-series data.\n\n3. Histogram\n\nHistograms are used to display the distribution of a single continuous variable. \n\n4. Bar Plot\n\nBar plots are effective for displaying and comparing the values of different categories or groups.\n\n5. Box Plot\n\nBox plots are used to visualize the distribution of a continuous variable across different categories.\n'

# %% [markdown]
# # Question 2

# %% [markdown]
# 2: Load the "fmri" dataset using the load_dataset function of seaborn. Plot a line plot using x =
# "timepoint" and y = "signal" for different events and regions.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the "fmri" dataset
fmri_data = sns.load_dataset("fmri")

# Plot line plot
sns.lineplot(x='timepoint', y='signal', hue='event', style='region', data=fmri_data)

# Set plot labels and title
plt.xlabel('Timepoint')
plt.ylabel('Signal')
plt.title('FMRI Signal Over Time for Different Events and Regions')

# Show the plot
plt.show()

# %% [markdown]
# # Question 3

# %% [markdown]
# Load the "titanic" dataset using the load_dataset function of seaborn. Plot two box plots using x =
# 'pclass', y = 'age' and y = 'fare'.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the "titanic" dataset
titanic_data = sns.load_dataset("titanic")

# Create box plots
plt.figure(figsize=(12, 6))

# Box plot for 'age'
plt.subplot(1, 2, 1)
sns.boxplot(x='pclass', y='age', data=titanic_data)
plt.title('Box Plot of Age by Pclass')

# Box plot for 'fare'
plt.subplot(1, 2, 2)
sns.boxplot(x='pclass', y='fare', data=titanic_data)
plt.title('Box Plot of Fare by Pclass')

# Adjust layout
plt.tight_layout()

# Show the plots
plt.show()

# %% [markdown]
# # Question 4

# %% [markdown]
# Use the "diamonds" dataset from seaborn to plot a histogram for the 'price' column. Use the hue
# parameter for the 'cut' column of the diamonds dataset.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the "diamonds" dataset
diamonds_data = sns.load_dataset("diamonds")

# Plot histogram with hue
plt.figure(figsize=(10, 6))
sns.histplot(data=diamonds_data, x='price', hue='cut', multiple='stack', bins=30, kde=True)

# Set plot labels and title
plt.xlabel('Price')
plt.ylabel('Count')
plt.title('Histogram of Diamond Prices with Cut Comparison')

# Show the plot
plt.show()

# %% [markdown]
# # Question 5

# %% [markdown]
# Use the "iris" dataset from seaborn to plot a pair plot. Use the hue parameter for the "species" column
# of the iris dataset.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the "iris" dataset
iris_data = sns.load_dataset("iris")

# Create a pair plot with hue
sns.pairplot(iris_data, hue='species', height=2.5)

# Show the plot
plt.show()

# %% [markdown]
# # Question 6

# %% [markdown]
# Use the "flights" dataset from seaborn to plot a heatmap.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the "flights" dataset
flights_data = sns.load_dataset("flights")

# Reshape the data to create a pivot table for the heatmap
flights_pivot = flights_data.pivot_table(index='month', columns='year', values='passengers')

# Create a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(flights_pivot, cmap='viridis', annot=True, fmt='d', linewidths=.5)

# Set plot labels and title
plt.xlabel('Year')
plt.ylabel('Month')
plt.title('Number of Passengers (Heatmap)')

# Show the plot
plt.show()
